# %%
import numpy as np
import pandas as pd

# %%
grades = {
    "Atil": 50,
    "Ayse": 60,
    "Atlas": 30
}

# %%
s1=pd.Series(grades)
s1
# Out:
# Atil     50
# Ayse     60
# Atlas    30
# dtype: int64

# %%
result1=pd.Series([10,5,100], index=["Atil" , "Ayse" , "Atlas"])
result2=pd.Series([120,50,10], index=["Atil" , "Ayse" , "Atlas"])

# %%
result1
# Out:
# Atil      10
# Ayse       5
# Atlas    100
# dtype: int64

# %%
final_result=result1+result2
final_result
# Out:
# Atil     130
# Ayse      55
# Atlas    110
# dtype: int64

# %%
diff1=pd.Series([20,30,40,50], index=['A','B','C','D'])
diff2=pd.Series([10,5,3,1], index=['A','C','F','G'])

# %%
diff_sum=diff1+diff2
diff_sum
# Out:
# A    30.0
# B     NaN
# C    45.0
# D     NaN
# F     NaN
# G     NaN
# dtype: float64

# %%
data = np.random.rand(4,3)
data
# Out:
# array([[0.53769619, 0.86132889, 0.75600876],
#        [0.01374897, 0.50439314, 0.98443404],
#        [0.89809344, 0.71063516, 0.74694171],
#        [0.08333335, 0.48105024, 0.94786555]])

# %%
pd.Series(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_224/4077153161.py in <cell line: 0>()
# ----> 1 pd.Series(data)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     582                 data = data.copy()
#     583         else:
# --> 584             data = sanitize_array(data, index, dtype, copy)
#     585
#     586             manager = _get_option("mode.data_manager", silent=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/construction.py in sanitize_array(data, index, dtype, copy, allow_2d)
#     657                 subarr = maybe_infer_to_datetimelike(subarr)
#     658
# --> 659     subarr = _sanitize_ndim(subarr, data, dtype, index, allow_2d=allow_2d)
#     660
#     661     if isinstance(subarr, np.ndarray):
#
# ...

# %%
df=pd.DataFrame(data)
df
# Out:
#           0         1         2
# 0  0.537696  0.861329  0.756009
# 1  0.013749  0.504393  0.984434
# 2  0.898093  0.710635  0.746942
# 3  0.083333  0.481050  0.947866

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
col0 = df[0]
col0,type(col0)
# Out:
# (0    0.537696
#  1    0.013749
#  2    0.898093
#  3    0.083333
#  Name: 0, dtype: float64,
#  pandas.core.series.Series)

# %%
df= pd.DataFrame(
    data,
    index=["Zeynep", "Atil" , "Mehmet", "Atlas"],
    columns=["maas", "yas", "kıdem"]
)
df
# Out:
#             maas       yas     kıdem
# Zeynep  0.537696  0.861329  0.756009
# Atil    0.013749  0.504393  0.984434
# Mehmet  0.898093  0.710635  0.746942
# Atlas   0.083333  0.481050  0.947866

# %%
df[["yas","maas"]]
# Out:
#              yas      maas
# Zeynep  0.861329  0.537696
# Atil    0.504393  0.013749
# Mehmet  0.710635  0.898093
# Atlas   0.481050  0.083333

# %%
df.loc["Atil"]
# Out:
# maas     0.013749
# yas      0.504393
# kıdem    0.984434
# Name: Atil, dtype: float64

# %%
df.iloc[:1]
# Out:
#             maas       yas     kıdem
# Zeynep  0.537696  0.861329  0.756009

# %%
df["extra"]=10
new_df=df
new_df
# Out:
#             maas       yas     kıdem  extra
# Zeynep  0.537696  0.861329  0.756009     10
# Atil    0.013749  0.504393  0.984434     10
# Mehmet  0.898093  0.710635  0.746942     10
# Atlas   0.083333  0.481050  0.947866     10

# %%
new_df.drop("extra", axis=1)
# Out:
#             maas       yas     kıdem
# Zeynep  0.537696  0.861329  0.756009
# Atil    0.013749  0.504393  0.984434
# Mehmet  0.898093  0.710635  0.746942
# Atlas   0.083333  0.481050  0.947866

# %%
new_df2.drop("extra", axis=1)

# %%
new_df
# Out:
#             maas       yas     kıdem  extra
# Zeynep  0.537696  0.861329  0.756009     10
# Atil    0.013749  0.504393  0.984434     10
# Mehmet  0.898093  0.710635  0.746942     10
# Atlas   0.083333  0.481050  0.947866     10

# %%
new_df.drop("extra" , axis=1 , inplace=True )
new_df
# Out:
#             maas       yas     kıdem
# Zeynep  0.537696  0.861329  0.756009
# Atil    0.013749  0.504393  0.984434
# Mehmet  0.898093  0.710635  0.746942
# Atlas   0.083333  0.481050  0.947866

# %%
new_df_3=new_df.drop("Mehmet")
new_df_3
# Out:
#             maas       yas     kıdem
# Zeynep  0.537696  0.861329  0.756009
# Atil    0.013749  0.504393  0.984434
# Atlas   0.083333  0.481050  0.947866

# %%
new_df.loc["Atlas", "maas"]=100
new_df
# Out:
#               maas       yas     kıdem
# Zeynep    0.537696  0.861329  0.756009
# Atil      0.013749  0.504393  0.984434
# Mehmet    0.898093  0.710635  0.746942
# Atlas   100.000000  0.481050  0.947866

# %%
new_df.iloc[2,0]=100
new_df
# Out:
#               maas       yas     kıdem
# Zeynep    0.537696  0.861329  0.756009
# Atil      0.013749  0.504393  0.984434
# Mehmet  100.000000  0.710635  0.746942
# Atlas   100.000000  0.481050  0.947866

# %%
new_df>0
# Out:
#         maas   yas  kıdem
# Zeynep  True  True   True
# Atil    True  True   True
# Mehmet  True  True   True
# Atlas   True  True   True

# %%
new_df[new_df>1]
# Out:
#          maas  yas  kıdem
# Zeynep    NaN  NaN    NaN
# Atil      NaN  NaN    NaN
# Mehmet  100.0  NaN    NaN
# Atlas   100.0  NaN    NaN

# %%
new_df[new_df["maas"]>1]
# Out:
#          maas       yas     kıdem
# Mehmet  100.0  0.710635  0.746942
# Atlas   100.0  0.481050  0.947866

# %%
new_df[new_df["yas"]>0.3]
# Out:
#               maas       yas     kıdem
# Zeynep    0.537696  0.861329  0.756009
# Atil      0.013749  0.504393  0.984434
# Mehmet  100.000000  0.710635  0.746942
# Atlas   100.000000  0.481050  0.947866

# %%
rf=df.reset_index()
rf
# Out:
#     index        maas       yas     kıdem
# 0  Zeynep    0.537696  0.861329  0.756009
# 1    Atil    0.013749  0.504393  0.984434
# 2  Mehmet  100.000000  0.710635  0.746942
# 3   Atlas  100.000000  0.481050  0.947866

# %%
rf.loc[0]
# Out:
# index      Zeynep
# maas     0.537696
# yas      0.861329
# kıdem    0.756009
# Name: 0, dtype: object

# %%
df.reset_index(drop=True)
# Out:
#          maas       yas     kıdem
# 0    0.537696  0.861329  0.756009
# 1    0.013749  0.504393  0.984434
# 2  100.000000  0.710635  0.746942
# 3  100.000000  0.481050  0.947866

# %%
ni=["zy","at","mh","al"]
df["ni"]=ni
df
# Out:
#               maas       yas     kıdem  ni
# Zeynep    0.537696  0.861329  0.756009  zy
# Atil      0.013749  0.504393  0.984434  at
# Mehmet  100.000000  0.710635  0.746942  mh
# Atlas   100.000000  0.481050  0.947866  al

# %%
df.set_index("ni",inplace=True)
df
# Out:
#           maas       yas     kıdem
# ni
# zy    0.537696  0.861329  0.756009
# at    0.013749  0.504393  0.984434
# mh  100.000000  0.710635  0.746942
# al  100.000000  0.481050  0.947866

# %%
df.loc["at"]
# Out:
# maas     0.013749
# yas      0.504393
# kıdem    0.984434
# Name: at, dtype: float64

# %%
w=pd.read_excel("/content/sample_data/6-weather.xlsx")
w
# Out:
#    Istanbul  New York  Amsterdam  Paris
# 0        20        10         15     12
# 1        21        10         17     14
# 2        20        13         18     15
# 3        22        14         19     18
# 4        25        15         15     20
# 5        28        13         22     16
# 6        15        12         15     15
# 7        20        15         14     14
# 8        22        16         16     16

# %%
w_tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_224/690253883.py in <cell line: 0>()
# ----> 1 w_tail()
#
# NameError: name 'w_tail' is not defined

# %%
w.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Istanbul   9 non-null      int64
#  1   New York   9 non-null      int64
#  2   Amsterdam  9 non-null      int64
#  3   Paris      9 non-null      int64
# dtypes: int64(4)
# memory usage: 420.0 bytes

# %%
w.describe()
# Out:
#         Istanbul   New York  Amsterdam      Paris
# count   9.000000   9.000000   9.000000   9.000000
# mean   21.444444  13.111111  16.777778  15.555556
# std     3.609401   2.147350   2.538591   2.351123
# min    15.000000  10.000000  14.000000  12.000000
# 25%    20.000000  12.000000  15.000000  14.000000
# 50%    21.000000  13.000000  16.000000  15.000000
# 75%    22.000000  15.000000  18.000000  16.000000
# max    28.000000  16.000000  22.000000  20.000000

# %%
w.count()
# Out:
# Istanbul     9
# New York     9
# Amsterdam    9
# Paris        9
# dtype: int64

# %%
w.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_224/1804309358.py in <cell line: 0>()
# ----> 1 w.shape(9,4)
#
# TypeError: 'tuple' object is not callable

# %%
w.isna()
# Out:
#    Istanbul  New York  Amsterdam  Paris
# 0     False     False      False  False
# 1     False     False      False  False
# 2     False     False      False  False
# 3     False     False      False  False
# 4     False     False      False  False
# 5     False     False      False  False
# 6     False     False      False  False
# 7     False     False      False  False
# 8     False     False      False  False

# %%
w.isna().sum()
# Out:
# Istanbul     0
# New York     0
# Amsterdam    0
# Paris        0
# dtype: int64
